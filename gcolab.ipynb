# %% [markdown]
# # **Prechecks**

# %%
import tensorflow as tf
import torch

print(torch.cuda.is_available())

print(tf.test.gpu_device_name())

# !nvidia-smi

# %% [markdown]
# Activate Drive, upload the dataset and clone my repo

# %%
# !git clone https://github.com/JulianGR/ECG_GAN_Stress

# !cp ./drive/My\ Drive/grouptwo_train.csv ./ECG_GAN_Stress/gan
# !cp ./drive/My\ Drive/grouptwo_test.csv ./ECG_GAN_Stress/gan

# %cd ECG_GAN_Stress/gan

# %% [markdown]
# ---

# %% [markdown]
# # **Debugging**

# %%
# %cd ../..
# !rm -r ./ECG_GAN_Stress/

# %%
# !rm -r ./your_path

# %% [markdown]
# ---

# %% [markdown]
# # **Start Training**

# %%
# !python3 train.py
# !cp -r ./your_path/ ../../drive/My\ Drive/group2/
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 175
# /content/ECG_GAN_Stress/Model.py:40: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   nn.init.normal(self.T, 0,1)
# 100% 36/36 [10:36<00:00, 17.68s/it]

# %% [markdown]
# zip it and download the zip if the copying to your Drive fails

# %%
# !zip -r ../../group2.zip ./your_path/

# %% [markdown]
# # **Plots**
# Plotting he first row of the processed files is a good idea. They should look more or less like the one below

# %%
# %cd ../..

# %%
# !cp ./drive/My\ Drive/rawnorm.csv ./
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("./rawnorm.csv", header=None)


#ax = df.transpose().plot(grid=True,  legend=True, figsize=(20,10))
ax = df.plot(grid=True,  legend=True, figsize=(20,10))
plt.show()
